# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Vishal/Desktop/coaster_db.csv',encoding='latin')

# %%
df.head(3)
# Out:
#                              coaster_name            Length             Speed  \
# 0                      Switchback Railway  600Â ft (180Â m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway               NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)               NaN               NaN
#
#                          Location   Status     Opening date   Type  \
# 0                    Coney Island  Removed  JuneÂ 16,Â 1884   Wood
# 1                   Sea Lion Park  Removed             1895   Wood
# 2  Cleveland, Ohio, United States   Closed              NaN  Other
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  ...  6 mph
# 1            Lina Beecher                NaN          NaN  ...     NaN
# 2                     NaN                NaN          NaN  ...     NaN
#
#      speed2 speed1_value speed1_unit speed_mph height_value height_unit  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.select_dtypes(include='float64').columns
# Out:
# Index(['Inversions', 'latitude', 'longitude', 'speed1_value', 'speed_mph',
#        'height_value', 'height_ft', 'Gforce_clean'],
#       dtype='object')

# %%
df.select_dtypes(include='int64').columns
# Out:
# Index(['year_introduced', 'Inversions_clean'], dtype='object')

# %%
df.select_dtypes(include='float64').isna().sum()
# Out:
# Inversions      155
# latitude        275
# longitude       275
# speed1_value    150
# speed_mph       150
# height_value    122
# height_ft       916
# Gforce_clean    725
# dtype: int64

# %%
df.select_dtypes(include='int64').isna().sum()
# Out:
# year_introduced     0
# Inversions_clean    0
# dtype: int64

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# 1. Dropping irrelivant Columns and Row
# 2. Identifying Duplicate Values
# 3. Renaming columns
# 4. Feature Creation

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# Removing Columns
df = df[['coaster_name', #'Length', 'Speed', 
         'Location', #'Status', 'Opening date',
       #'Type',
         'Manufacturer',
         #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean',# 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', #'height_value', 'height_unit',
         'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.head(3)
# Out:
#                              coaster_name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
#
#              Manufacturer  year_introduced  latitude  longitude Type_Main  \
# 0  LaMarcus Adna Thompson             1884    40.574    -73.978      Wood
# 1            Lina Beecher             1895    40.578    -73.979      Wood
# 2                     NaN             1896    41.580    -81.570     Other
#
#   opening_date_clean  speed_mph  height_ft  Inversions_clean  Gforce_clean
# 0         1884-06-16        6.0        NaN                 0           2.9
# 1         1895-01-01        NaN        NaN                 1          12.0
# 2                NaN        NaN        NaN                 0           NaN

# %%
df.shape
# Out:
# (1087, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Manufacturer        1028 non-null   object
#  3   year_introduced     1087 non-null   int64
#  4   latitude            812 non-null    float64
#  5   longitude           812 non-null    float64
#  6   Type_Main           1087 non-null   object
#  7   opening_date_clean  837 non-null    object
#  8   speed_mph           937 non-null    float64
#  9   height_ft           171 non-null    float64
#  10  Inversions_clean    1087 non-null   int64
#  11  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 102.0+ KB

# %%
# Changing Format
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])

# %%
df.head(2)
# Out:
#          coaster_name       Location            Manufacturer  year_introduced  \
# 0  Switchback Railway   Coney Island  LaMarcus Adna Thompson             1884
# 1   Flip Flap Railway  Sea Lion Park            Lina Beecher             1895
#
#    latitude  longitude Type_Main opening_date_clean  speed_mph  height_ft  \
# 0    40.574    -73.978      Wood         1884-06-16        6.0        NaN
# 1    40.578    -73.979      Wood         1895-01-01        NaN        NaN
#
#    Inversions_clean  Gforce_clean
# 0                 0           2.9
# 1                 1          12.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Manufacturer        1028 non-null   object
#  3   year_introduced     1087 non-null   int64
#  4   latitude            812 non-null    float64
#  5   longitude           812 non-null    float64
#  6   Type_Main           1087 non-null   object
#  7   opening_date_clean  837 non-null    datetime64[ns]
#  8   speed_mph           937 non-null    float64
#  9   height_ft           171 non-null    float64
#  10  Inversions_clean    1087 non-null   int64
#  11  Gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 102.0+ KB

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
# Renaming columns
df = df.rename(columns={'coaster_name':'Coaster_Name','year_introduced':'Year_Introduced',
       'opening_date_clean':'Opening_Date', 'speed_mph':'Speed_mph',
        'Inversions_clean':'Inversion', 'Gforce_clean':'Gforce'})

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'height_ft', 'Inversion', 'Gforce'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Coaster_Name         0
# Location             0
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# height_ft          916
# Inversion            0
# Gforce             725
# dtype: int64

# %%
# Finding Duplicate Row

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, height_ft, Inversion, Gforce]
# Index: []

# %%
# Finding Duplicate coaster_Name
df[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                                            Manufacturer  Year_Introduced  \
# 43                                   Traver Engineering             1927
# ...

# %%
# Checking an Example Duplicate
df.query("Coaster_Name == 'Crystal Beach Cyclone'")
# Out:
#              Coaster_Name            Location        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     height_ft  Inversion  Gforce
# 39        NaN          0     4.0
# 43        NaN          0     4.0

# %%
df =df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].reset_index(drop=True)

# %%
df.shape
# Out:
# (990, 12)

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#              Manufacturer  Year_Introduced  latitude  longitude Type_Main  \
# 0  LaMarcus Adna Thompson             1884   40.5740   -73.9780      Wood
# 1            Lina Beecher             1895   40.5780   -73.9790      Wood
# 2                     NaN             1896   41.5800   -81.5700     Other
# 3          Edwin Prescott             1901   40.5745   -73.9780     Steel
# 4          Edwin Prescott             1901   39.3538   -74.4342     Steel
#
#   Opening_Date  Speed_mph  height_ft  Inversion  Gforce
# ...

# %%
# Checking an Example Duplicate
df.query("Coaster_Name == 'Crystal Beach Cyclone'")
# Out:
#              Coaster_Name            Location        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     height_ft  Inversion  Gforce
# 39        NaN          0     4.0

# %%
# Finding Duplicate coaster_Name
df[df.duplicated(subset=['Coaster_Name'])]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, height_ft, Inversion, Gforce]
# Index: []

# %% [raw]
# # All Clean Duplicate Values Completes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Coaster_Name     990 non-null    object
#  1   Location         990 non-null    object
#  2   Manufacturer     932 non-null    object
#  3   Year_Introduced  990 non-null    int64
#  4   latitude         783 non-null    float64
#  5   longitude        783 non-null    float64
#  6   Type_Main        990 non-null    object
#  7   Opening_Date     807 non-null    datetime64[ns]
#  8   Speed_mph        850 non-null    float64
#  9   height_ft        159 non-null    float64
#  10  Inversion        990 non-null    int64
#  11  Gforce           324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 92.9+ KB

# %%
df.isnull().sum()
# Out:
# Coaster_Name         0
# Location             0
# Manufacturer        58
# Year_Introduced      0
# latitude           207
# longitude          207
# Type_Main            0
# Opening_Date       183
# Speed_mph          140
# height_ft          831
# Inversion            0
# Gforce             666
# dtype: int64

# %% [markdown]
# # Feature Understanding
# 1. Plotting feature Distribution
#    . Histogram
#    . KDE
#    . BOxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
myplot = df['Year_Introduced'].value_counts().head(10)

# %%
myplot.plot(kind='bar',title='TOP 10 Year Coasters Introducted')
# Out:
# <Axes: title={'center': 'TOP 10 Year Coasters Introducted'}, xlabel='Year_Introduced'>

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'height_ft', 'Inversion', 'Gforce'],
#       dtype='object')

# %%
df['Speed_mph'].head()
# Out:
# 0    6.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Speed_mph, dtype: float64

# %%
myhistplot = df['Speed_mph'].plot(kind='hist',title='Coaster Speed MPH')

# %%
myhistplot = df['Speed_mph'].plot(kind='kde',title='Coaster Speed MPH')

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %%
myplot = df['Type_Main'].value_counts()

# %%
myplot.plot(kind='bar',title='Types_main Introducted')
# Out:
# <Axes: title={'center': 'Types_main Introducted'}, xlabel='Type_Main'>

# %%
myplot.plot(kind='hist',title='Types_main Introducted')
# Out:
# <Axes: title={'center': 'Types_main Introducted'}, ylabel='Frequency'>

# %%
myplot.plot(kind='kde',title='Types_main Introducted')
# Out:
# <Axes: title={'center': 'Types_main Introducted'}, ylabel='Density'>

# %% [markdown]
# # Feature Relationship
# 1. Scratterploy
# 2. Heatmap Correlation
# 3. Pairplkot
# 4. Groupby Comparisons

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'height_ft', 'Inversion', 'Gforce'],
#       dtype='object')

# %%
df.plot(kind='scatter',x='Speed_mph',y ='height_ft',title='Coaster Speed vs Height')
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.scatterplot(x='Speed_mph',y ='height_ft',data =df,hue='Year_Introduced',palette='viridis')
plt.title('Caster speed vs Height')
plt.show()

# %%
sns.pairplot(df, vars=['Year_Introduced','Speed_mph',
       'height_ft', 'Inversion', 'Gforce'],hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year_Introduced','Speed_mph',
       'height_ft', 'Inversion', 'Gforce']].dropna().corr()

# %%
df_corr
# Out:
#                  Year_Introduced  Speed_mph  height_ft  Inversion    Gforce
# Year_Introduced         1.000000   0.171978   0.135413  -0.209887  0.160247
# Speed_mph               0.171978   1.000000   0.733999  -0.028705  0.607383
# height_ft               0.135413   0.733999   1.000000  -0.079736  0.466482
# Inversion              -0.209887  -0.028705  -0.079736   1.000000  0.275991
# Gforce                  0.160247   0.607383   0.466482   0.275991  1.000000

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Question:-
# find top 10 location with Average Speed with bharplot
